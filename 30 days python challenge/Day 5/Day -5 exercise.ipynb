# %% [markdown]
# # Task 1- find largest numbers

# %%
numbers = [10, 50, 20, 90, 30]

print(max(numbers))
# Out:
# 90

# %% [markdown]
# # Task 2- average calculator

# %%
marks = [80, 90, 70, 60]

average = sum(marks) / len(marks) 

print(average)
# Out:
# 75.0

# %% [markdown]
# # Task 3- product inventory

# %%
products = ["Laptop", "Mouse"]

products.append("Keyboard")

print(products)
# Out:
# ['Laptop', 'Mouse', 'Keyboard']

# %%
products.remove("Mouse")

print(products)
# Out:
# ['Laptop', 'Keyboard']

# %% [markdown]
# # Day 5 Goal
#     Store multiple values
#     Access list elements
#     Modify lists
#     Use loops with lists
#     Perform calculations on collections
#     Understand nested structures
#     Differentiate lists and tuples
