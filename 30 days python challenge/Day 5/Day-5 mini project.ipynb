# %% [markdown]
# # Day 5 mini project - **Expense Tracker**
# This project combines:
#
#     Lists
#     Loops
#     Calculations
#     Functions

# %%
# Expense Tracker
expenses = []

while True:

    print("\n===== EXPENSE TRACKER =====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Total Spending")
    print("4. Highest Expense")
    print("5. Exit")

    choice = input("Enter choice: ")

    if choice == "1":

        amount = float(input("Enter expense amount: "))

        expenses.append(amount)

        print("Expense Added")

    elif choice == "2":

        print("\nExpenses List:")

        for expense in expenses:
            print(expense)

    elif choice == "3":

        print(f"Total Spending: ₹{sum(expenses)}")

    elif choice == "4":

        if len(expenses) > 0:
            print(f"Highest Expense: ₹{max(expenses)}")

        else:
            print("No expenses found")

    elif choice == "5":

        print("Exiting Program")
        break

    else:
        print("Invalid Choice")
# Out:
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Expense Added
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Invalid Choice
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Expense Added
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Invalid Choice
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
#
# Expenses List:
# 1.0
# 12999.0
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Highest Expense: ₹12999.0
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Highest Expense
# 5. Exit
# Exiting Program
