# %% [markdown]
# # Day 9- Tasks
# ---

# %% [markdown]
# # Task 1- Student dataset

# %%
import pandas as pd

data = {

    "Name": ["Kunal", "Rahul", "Aman"],

    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks
# 0  Kunal     85
# 1  Rahul     90
# 2   Aman     78

# %% [markdown]
# # Task 2- Filter High Marks

# %%
top_students = df[df["Marks"] > 80]

print(top_students)
# Out:
#     Name  Marks
# 0  Kunal     85
# 1  Rahul     90
